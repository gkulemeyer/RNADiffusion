# %% [markdown]
# # Deprecated Notebook
#
# Este notebook fue dividido en:
# - `profiler_run.ipynb` (entrenamiento + trace)
# - `profiler_summary.ipynb` (lectura de traces + summary CSV)
# - `extended_profiler.ipynb` (analisis y graficas)

# %%
from pathlib import Path
print("Usa profiler_run.ipynb, profiler_summary.ipynb y extended_profiler.ipynb en esta carpeta:")
print(Path.cwd() / "profiler")
